# %% [markdown]
# ## Basic Linguistic Algorithms Using PreTrainedModels

# %% [markdown]
# #### Table of Contents
# - **[Spark2.3 Set Up](#section1)**
# - **[Explain Document](#section2)**
# - **[Clean Stop words](#section3)**
# - **[Entiry recognization](#section4)**
# - **[Clean slang](#section5)**
# - **[Spell Checker](#section6)**
# - **[Sentiment Analysis](#section7)**
# - **[Matching Chunks](#section8)**
# - **[Match_Date_Phrase](#section9)**

# %% [markdown]
# ### Spark2.3 Set Up
# <a id='section1'></a>

# %%
import os
import sys
import findspark
import pandas as pd
os.environ["JAVA_HOME"] = "/usr/lib64/jvm/java-1.8.0-openjdk-1.8.0"
os.environ["PATH"] = os.environ["JAVA_HOME"] + "/bin:" + os.environ["PATH"]
os.environ["SPARK_HOME"] = "/dfs/is/home/m292915/spark-2.3.0-bin-hadoop2.7"
findspark.init()
jar_path='/dfs/is/home/m292915/spark-2.3.0-bin-hadoop2.7/jars/'

from pyspark.sql import SparkSession
spark = SparkSession.builder \
        .appName("Spark NLP") \
        .master("local[*]") \
        .config("spark.driver.memory", "16G") \
        .config("spark.serializer", "org.apache.spark.serializer.KryoSerializer") \
        .config("spark.kryoserializer.buffer.max", "1000M") \
        .config("spark.driver.maxResultSize", "0")\
        .config("spark.jars", "{}spark-nlp-spark23_2.11-2.5.5.jar,{}spark-nlp-spark23-assembly-2.5.5.jar".format(jar_path,jar_path)) \
        .getOrCreate()

import sparknlp
sparknlp.start(spark23=True)
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://mcsbx04.mcloud.merckgroup.com:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v2.3.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Spark NLP</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
import sparknlp
print("Spark NLP version", sparknlp.version())
print("Apache Spark version:", spark.version)
# Out:
# Spark NLP version 2.6.0
# Apache Spark version: 2.3.0

# %%
text = '''The Merck Group, branded and commonly known as Merck, is a German multinational pharmaceutical, chemical and life sciences company headquartered in Darmstadt, with about 56,000 employees and present in 66 countries. 
The group includes around 250 companies; the main company is Merck KGaA in Germany. 
Merck was founded in 1668 and is the world's oldest operating chemical and pharmaceutical company, as well as one of the largest pharmaceutical companies in the world'''

# %% [markdown]
# ### Explain Document
# <a id='section2'></a>

# %% [markdown]
# **Stages in ml**
# - DocumentAssembler
# - SentenceDetector
# - Tokenizer
# - Lemmatizer
# - Stemmer
# - Part of Speech
# - SpellChecker (Norvig)
#
# **Stages in DL**
# - DocumentAssembler
# - SentenceDetector
# - Tokenizer
# - NER (NER with GloVe 100D embeddings, CoNLL2003 dataset)
# - Lemmatizer
# - Stemmer
# - Part of Speech
# - SpellChecker (Norvig)
#
# download pretrained models from https://github.com/JohnSnowLabs/spark-nlp-models

# %%
from sparknlp.pretrained import PretrainedPipeline
explain_dl=PretrainedPipeline.from_disk("/dfs/is/home/m292915/spark_nlp/sparknlp_pipelines/explain_document_dl_en")
explain_ml=PretrainedPipeline.from_disk("/dfs/is/home/m292915/spark_nlp/sparknlp_pipelines/explain_document_ml_en")
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-3-440e44270ab8> in <module>
#       1 from sparknlp.pretrained import PretrainedPipeline
# ----> 2 explain_dl=PretrainedPipeline.from_disk("/dfs/is/home/m292915/spark_nlp/sparknlp_pipelines/explain_document_dl_en")
#       3 explain_ml=PretrainedPipeline.from_disk("/dfs/is/home/m292915/spark_nlp/sparknlp_pipelines/explain_document_ml_en")
#
# ~/.conda/envs/sparknlp26/lib/python3.7/site-packages/sparknlp/pretrained.py in from_disk(path, parse_embeddings)
#      96     @staticmethod
#      97     def from_disk(path, parse_embeddings=False):
# ---> 98         return PretrainedPipeline(None, None, None, parse_embeddings, path)
#      99
#     100     def annotate(self, target, column=None):
#
# ~/.conda/envs/sparknlp26/lib/python3.7/site-packages/sparknlp/pretrained.py in __init__(self, name, lang, remote_loc, parse_embeddings, disk_location)
#      92         else:
#      93             self.model = PipelineModel.load(disk_location)
# ---> 94         self.light_model = LightPipeline(self.model, parse_embeddings)
#      95
#      96     @staticmethod
#
# ~/.conda/envs/sparknlp26/lib/python3.7/site-packages/sparknlp/base.py in __init__(self, pipelineModel, parse_embeddings)
#      15     def __init__(self, pipelineModel, parse_embeddings=False):
#      16         self.pipeline_model = pipelineModel
# ---> 17         self._lightPipeline = _internal._LightPipeline(pipelineModel, parse_embeddings).apply()
#      18
#      19     @staticmethod
#
# ~/.conda/envs/sparknlp26/lib/python3.7/site-packages/sparknlp/internal.py in __init__(self, pipelineModel, parse_embeddings)
#     219 class _LightPipeline(ExtendedJavaWrapper):
#     220     def __init__(self, pipelineModel, parse_embeddings):
# --> 221         super(_LightPipeline, self).__init__("com.johnsnowlabs.nlp.LightPipeline", pipelineModel._to_java(), parse_embeddings)
#     222
#     223 # ==================
#
# ~/spark-2.3.0-bin-hadoop2.7/python/pyspark/ml/pipeline.py in _to_java(self)
#     314         java_stages = gateway.new_array(cls, len(self.stages))
#     315         for idx, stage in enumerate(self.stages):
# --> 316             java_stages[idx] = stage._to_java()
#     317
#     318         _java_obj =\
#
# ~/spark-2.3.0-bin-hadoop2.7/python/pyspark/ml/wrapper.py in _to_java(self)
#     195         :return: Java object equivalent to this instance.
#     196         """
# --> 197         self._transfer_params_to_java()
#     198         return self._java_obj
#     199
#
# ~/spark-2.3.0-bin-hadoop2.7/python/pyspark/ml/wrapper.py in _transfer_params_to_java(self)
#     122         for param in self.params:
#     123             if param in paramMap:
# --> 124                 pair = self._make_java_param_pair(param, paramMap[param])
#     125                 self._java_obj.set(pair)
#     126
#
# ~/spark-2.3.0-bin-hadoop2.7/python/pyspark/ml/wrapper.py in _make_java_param_pair(self, param, value)
#     111         sc = SparkContext._active_spark_context
#     112         param = self._resolveParam(param)
# --> 113         java_param = self._java_obj.getParam(param.name)
#     114         java_value = _py2java(sc, value)
#     115         return java_param.w(java_value)
#
# ~/spark-2.3.0-bin-hadoop2.7/python/lib/py4j-0.10.6-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1158         answer = self.gateway_client.send_command(command)
#    1159         return_value = get_return_value(
# -> 1160             answer, self.gateway_client, self.target_id, self.name)
#    1161
#    1162         for temp_arg in temp_args:
#
# ~/spark-2.3.0-bin-hadoop2.7/python/pyspark/sql/utils.py in deco(*a, **kw)
#      61     def deco(*a, **kw):
#      62         try:
# ---> 63             return f(*a, **kw)
#      64         except py4j.protocol.Py4JJavaError as e:
#      65             s = e.java_exception.toString()
#
# ~/spark-2.3.0-bin-hadoop2.7/python/lib/py4j-0.10.6-src.zip/py4j/protocol.py in get_return_value(answer, gateway_client, target_id, name)
#     318                 raise Py4JJavaError(
#     319                     "An error occurred while calling {0}{1}{2}.\n".
# --> 320                     format(target_id, ".", name), value)
#     321             else:
#     322                 raise Py4JError(
#
# Py4JJavaError: An error occurred while calling o135.getParam.
# : java.util.NoSuchElementException: Param detectLists does not exist.
# 	at org.apache.spark.ml.param.Params$$anonfun$getParam$2.apply(params.scala:729)
# 	at org.apache.spark.ml.param.Params$$anonfun$getParam$2.apply(params.scala:729)
# 	at scala.Option.getOrElse(Option.scala:121)
# 	at org.apache.spark.ml.param.Params$class.getParam(params.scala:728)
# 	at org.apache.spark.ml.PipelineStage.getParam(Pipeline.scala:42)
# 	at sun.reflect.GeneratedMethodAccessor46.invoke(Unknown Source)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:357)
# 	at py4j.Gateway.invoke(Gateway.java:282)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.GatewayConnection.run(GatewayConnection.java:214)
# 	at java.lang.Thread.run(Thread.java:748)

# %%
result_explain_dl = explain_dl.annotate(text)
result_explain_ml= explain_ml.annotate(text)

# %%
print(result_explain_dl.keys())
print(result_explain_dl.keys())
# Out:
# dict_keys(['entities', 'stem', 'checked', 'lemma', 'document', 'pos', 'token', 'ner', 'embeddings', 'sentence'])
# dict_keys(['entities', 'stem', 'checked', 'lemma', 'document', 'pos', 'token', 'ner', 'embeddings', 'sentence'])

# %%
dl_df = pd.DataFrame({'token':result_explain_dl['token'], 'dl_ner_label':result_explain_dl['ner'],
                      'dl_spell_corrected':result_explain_dl['checked'], 'dl_POS':result_explain_dl['pos'],
                      'dl_lemmas':result_explain_dl['lemma'], 'dl_stems':result_explain_dl['stem']})
ml_df = pd.DataFrame({'token':result_explain_ml['token'], 
                      'ml_corrected':result_explain_ml['spell'], 'ml_POS':result_explain_ml['pos'],
                      'ml_lemmas':result_explain_ml['lemmas'], 'ml_stems':result_explain_ml['stems']})
dl_df.merge(ml_df,on='token').drop_duplicates().head(10)
# Out:
#        token dl_ner_label dl_spell_corrected dl_POS dl_lemmas  dl_stems  \
# 0        The            O                The     DT       The       the
# 4      Merck        B-ORG              Merck    NNP     Merck     merck
# 20     Group        I-ORG              Group    NNP     Group     group
# 21         ,            O                  ,      ,         ,         ,
# 46   branded            O            branded    VBD     brand     brand
# 47       and            O                and     CC       and       and
# 72  commonly            O           commonly     RB  commonly  commonli
# 73     known            O              known    VBN      know     known
# 74        as            O                 as     IN        as         a
# 75        as            O                 as     IN        as         a
#
#    ml_corrected ml_POS ml_lemmas  ml_stems
# 0           The     DT       The       the
# 4         Merck    NNP     Merck     merck
# 20        Group    NNP     Group     group
# 21            ,      ,         ,         ,
# 46      branded    VBD     brand     brand
# 47          and     CC       and       and
# 72     commonly     RB  commonly  commonli
# 73        known    VBN      know     known
# 74           as     IN        as         a
# 75           as     RB        as         a

# %%
detailed_result_explain_dl = explain_dl.fullAnnotate(text)

# %%
detailed_result_explain_dl
# Out:
# [{'entities': [Annotation(chunk, 4, 14, Merck Group, {'entity': 'ORG', 'sentence': '0', 'chunk': '0'}),
#    Annotation(chunk, 47, 51, Merck, {'entity': 'ORG', 'sentence': '0', 'chunk': '1'}),
#    Annotation(chunk, 59, 64, German, {'entity': 'MISC', 'sentence': '0', 'chunk': '2'}),
#    Annotation(chunk, 148, 156, Darmstadt, {'entity': 'LOC', 'sentence': '0', 'chunk': '3'}),
#    Annotation(chunk, 278, 287, Merck KGaA, {'entity': 'ORG', 'sentence': '2', 'chunk': '4'}),
#    Annotation(chunk, 292, 298, Germany, {'entity': 'LOC', 'sentence': '2', 'chunk': '5'}),
#    Annotation(chunk, 302, 306, Merck, {'entity': 'ORG', 'sentence': '3', 'chunk': '6'})],
#   'stem': [Annotation(token, 0, 2, the, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 4, 8, merck, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 10, 14, group, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 15, 15, ,, {'confidence': '0.0', 'sentence': '0'}),
#    Annotation(token, 17, 23, brand, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 25, 27, and, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 29, 36, commonli, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 38, 42, known, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 44, 45, a, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 47, 51, merck, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 52, 52, ,, {'confidence': '0.0', 'sentence': '0'}),
#    Annotation(token, 54, 55, i, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 57, 57, a, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 59, 64, german, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 66, 78, multin, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 80, 93, pharmaceut, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 94, 94, ,, {'confidence': '0.0', 'sentence': '0'}),
#    Annotation(token, 96, 103, chemic, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 105, 107, and, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 109, 112, life, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 114, 121, scienc, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 123, 129, compani, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 131, 143, headquart, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 145, 146, in, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 148, 156, darmstadt, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 157, 157, ,, {'confidence': '0.0', 'sentence': '0'}),
#    Annotation(token, 159, 162, with, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 164, 168, about, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 170, 175, 56,000, {'confidence': '0.0', 'sentence': '0'}),
#    Annotation(token, 177, 185, employe, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 187, 189, and, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 191, 197, present, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 199, 200, in, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 202, 203, 66, {'confidence': '0.0', 'sentence': '0'}),
#    Annotation(token, 205, 213, countri, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 214, 214, ., {'confidence': '0.0', 'sentence': '0'}),
#    Annotation(token, 217, 219, the, {'confidence': '1.0', 'sentence': '1'}),
#    Annotation(token, 221, 225, group, {'confidence': '1.0', 'sentence': '1'}),
#    Annotation(token, 227, 234, includ, {'confidence': '1.0', 'sentence': '1'}),
#    Annotation(token, 236, 241, around, {'confidence': '1.0', 'sentence': '1'}),
#    Annotation(token, 243, 245, 250, {'confidence': '0.0', 'sentence': '1'}),
#    Annotation(token, 247, 255, compani, {'confidence': '1.0', 'sentence': '1'}),
#    Annotation(token, 256, 256, ;, {'confidence': '0.0', 'sentence': '1'}),
#    Annotation(token, 258, 260, the, {'confidence': '1.0', 'sentence': '2'}),
#    Annotation(token, 262, 265, main, {'confidence': '1.0', 'sentence': '2'}),
#    Annotation(token, 267, 273, compani, {'confidence': '1.0', 'sentence': '2'}),
#    Annotation(token, 275, 276, i, {'confidence': '1.0', 'sentence': '2'}),
#    Annotation(token, 278, 282, merck, {'confidence': '1.0', 'sentence': '2'}),
#    Annotation(token, 284, 287, kgaa, {'confidence': '0.0', 'sentence': '2'}),
#    Annotation(token, 289, 290, in, {'confidence': '1.0', 'sentence': '2'}),
#    Annotation(token, 292, 298, germani, {'confidence': '1.0', 'sentence': '2'}),
#    Annotation(token, 299, 299, ., {'confidence': '0.0', 'sentence': '2'}),
#    Annotation(token, 302, 306, merck, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 308, 310, wa, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 312, 318, found, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 320, 321, in, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 323, 326, 1668, {'confidence': '0.0', 'sentence': '3'}),
#    Annotation(token, 328, 330, and, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 332, 333, i, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 335, 337, the, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 339, 345, world', {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 347, 352, oldest, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 354, 362, oper, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 364, 371, chemic, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 373, 375, and, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 377, 390, pharmaceut, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 392, 398, compani, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 399, 399, ,, {'confidence': '0.0', 'sentence': '3'}),
#    Annotation(token, 401, 402, a, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 404, 407, well, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 409, 410, a, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 412, 414, on, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 416, 417, of, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 419, 421, the, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 423, 429, largest, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 431, 444, pharmaceut, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 446, 454, compani, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 456, 457, in, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 459, 461, the, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 463, 467, world, {'confidence': '1.0', 'sentence': '3'})],
#   'checked': [Annotation(token, 0, 2, The, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 4, 8, Merck, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 10, 14, Group, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 15, 15, ,, {'confidence': '0.0', 'sentence': '0'}),
#    Annotation(token, 17, 23, branded, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 25, 27, and, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 29, 36, commonly, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 38, 42, known, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 44, 45, as, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 47, 51, Merck, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 52, 52, ,, {'confidence': '0.0', 'sentence': '0'}),
#    Annotation(token, 54, 55, is, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 57, 57, a, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 59, 64, German, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 66, 78, multinational, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 80, 93, pharmaceutical, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 94, 94, ,, {'confidence': '0.0', 'sentence': '0'}),
#    Annotation(token, 96, 103, chemical, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 105, 107, and, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 109, 112, life, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 114, 121, sciences, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 123, 129, company, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 131, 143, headquartered, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 145, 146, in, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 148, 156, Darmstadt, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 157, 157, ,, {'confidence': '0.0', 'sentence': '0'}),
#    Annotation(token, 159, 162, with, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 164, 168, about, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 170, 175, 56,000, {'confidence': '0.0', 'sentence': '0'}),
#    Annotation(token, 177, 185, employees, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 187, 189, and, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 191, 197, present, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 199, 200, in, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 202, 203, 66, {'confidence': '0.0', 'sentence': '0'}),
#    Annotation(token, 205, 213, countries, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 214, 214, ., {'confidence': '0.0', 'sentence': '0'}),
#    Annotation(token, 217, 219, The, {'confidence': '1.0', 'sentence': '1'}),
#    Annotation(token, 221, 225, group, {'confidence': '1.0', 'sentence': '1'}),
#    Annotation(token, 227, 234, includes, {'confidence': '1.0', 'sentence': '1'}),
#    Annotation(token, 236, 241, around, {'confidence': '1.0', 'sentence': '1'}),
#    Annotation(token, 243, 245, 250, {'confidence': '0.0', 'sentence': '1'}),
#    Annotation(token, 247, 255, companies, {'confidence': '1.0', 'sentence': '1'}),
#    Annotation(token, 256, 256, ;, {'confidence': '0.0', 'sentence': '1'}),
#    Annotation(token, 258, 260, the, {'confidence': '1.0', 'sentence': '2'}),
#    Annotation(token, 262, 265, main, {'confidence': '1.0', 'sentence': '2'}),
#    Annotation(token, 267, 273, company, {'confidence': '1.0', 'sentence': '2'}),
#    Annotation(token, 275, 276, is, {'confidence': '1.0', 'sentence': '2'}),
#    Annotation(token, 278, 282, Merck, {'confidence': '1.0', 'sentence': '2'}),
#    Annotation(token, 284, 287, KGaA, {'confidence': '0.0', 'sentence': '2'}),
#    Annotation(token, 289, 290, in, {'confidence': '1.0', 'sentence': '2'}),
#    Annotation(token, 292, 298, Germany, {'confidence': '1.0', 'sentence': '2'}),
#    Annotation(token, 299, 299, ., {'confidence': '0.0', 'sentence': '2'}),
#    Annotation(token, 302, 306, Merck, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 308, 310, was, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 312, 318, founded, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 320, 321, in, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 323, 326, 1668, {'confidence': '0.0', 'sentence': '3'}),
#    Annotation(token, 328, 330, and, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 332, 333, is, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 335, 337, the, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 339, 345, world's, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 347, 352, oldest, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 354, 362, operating, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 364, 371, chemical, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 373, 375, and, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 377, 390, pharmaceutical, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 392, 398, company, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 399, 399, ,, {'confidence': '0.0', 'sentence': '3'}),
#    Annotation(token, 401, 402, as, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 404, 407, well, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 409, 410, as, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 412, 414, one, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 416, 417, of, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 419, 421, the, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 423, 429, largest, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 431, 444, pharmaceutical, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 446, 454, companies, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 456, 457, in, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 459, 461, the, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 463, 467, world, {'confidence': '1.0', 'sentence': '3'})],
#   'lemma': [Annotation(token, 0, 2, The, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 4, 8, Merck, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 10, 14, Group, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 15, 15, ,, {'confidence': '0.0', 'sentence': '0'}),
#    Annotation(token, 17, 23, brand, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 25, 27, and, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 29, 36, commonly, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 38, 42, know, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 44, 45, as, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 47, 51, Merck, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 52, 52, ,, {'confidence': '0.0', 'sentence': '0'}),
#    Annotation(token, 54, 55, be, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 57, 57, a, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 59, 64, German, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 66, 78, multinational, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 80, 93, pharmaceutical, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 94, 94, ,, {'confidence': '0.0', 'sentence': '0'}),
#    Annotation(token, 96, 103, chemical, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 105, 107, and, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 109, 112, life, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 114, 121, science, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 123, 129, company, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 131, 143, headquarter, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 145, 146, in, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 148, 156, Darmstadt, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 157, 157, ,, {'confidence': '0.0', 'sentence': '0'}),
#    Annotation(token, 159, 162, with, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 164, 168, about, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 170, 175, 56,000, {'confidence': '0.0', 'sentence': '0'}),
#    Annotation(token, 177, 185, employee, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 187, 189, and, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 191, 197, present, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 199, 200, in, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 202, 203, 66, {'confidence': '0.0', 'sentence': '0'}),
#    Annotation(token, 205, 213, country, {'confidence': '1.0', 'sentence': '0'}),
#    Annotation(token, 214, 214, ., {'confidence': '0.0', 'sentence': '0'}),
#    Annotation(token, 217, 219, The, {'confidence': '1.0', 'sentence': '1'}),
#    Annotation(token, 221, 225, group, {'confidence': '1.0', 'sentence': '1'}),
#    Annotation(token, 227, 234, include, {'confidence': '1.0', 'sentence': '1'}),
#    Annotation(token, 236, 241, around, {'confidence': '1.0', 'sentence': '1'}),
#    Annotation(token, 243, 245, 250, {'confidence': '0.0', 'sentence': '1'}),
#    Annotation(token, 247, 255, company, {'confidence': '1.0', 'sentence': '1'}),
#    Annotation(token, 256, 256, ;, {'confidence': '0.0', 'sentence': '1'}),
#    Annotation(token, 258, 260, the, {'confidence': '1.0', 'sentence': '2'}),
#    Annotation(token, 262, 265, main, {'confidence': '1.0', 'sentence': '2'}),
#    Annotation(token, 267, 273, company, {'confidence': '1.0', 'sentence': '2'}),
#    Annotation(token, 275, 276, be, {'confidence': '1.0', 'sentence': '2'}),
#    Annotation(token, 278, 282, Merck, {'confidence': '1.0', 'sentence': '2'}),
#    Annotation(token, 284, 287, KGaA, {'confidence': '0.0', 'sentence': '2'}),
#    Annotation(token, 289, 290, in, {'confidence': '1.0', 'sentence': '2'}),
#    Annotation(token, 292, 298, Germany, {'confidence': '1.0', 'sentence': '2'}),
#    Annotation(token, 299, 299, ., {'confidence': '0.0', 'sentence': '2'}),
#    Annotation(token, 302, 306, Merck, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 308, 310, be, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 312, 318, founded, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 320, 321, in, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 323, 326, 1668, {'confidence': '0.0', 'sentence': '3'}),
#    Annotation(token, 328, 330, and, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 332, 333, be, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 335, 337, the, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 339, 345, world's, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 347, 352, old, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 354, 362, operate, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 364, 371, chemical, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 373, 375, and, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 377, 390, pharmaceutical, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 392, 398, company, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 399, 399, ,, {'confidence': '0.0', 'sentence': '3'}),
#    Annotation(token, 401, 402, as, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 404, 407, well, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 409, 410, as, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 412, 414, one, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 416, 417, of, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 419, 421, the, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 423, 429, large, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 431, 444, pharmaceutical, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 446, 454, company, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 456, 457, in, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 459, 461, the, {'confidence': '1.0', 'sentence': '3'}),
#    Annotation(token, 463, 467, world, {'confidence': '1.0', 'sentence': '3'})],
#   'document': [Annotation(document, 0, 467, The Merck Group, branded and commonly known as Merck, is a German multinational pharmaceutical, chemical and life sciences company headquartered in Darmstadt, with about 56,000 employees and present in 66 countries.
#    The group includes around 250 companies; the main company is Merck KGaA in Germany.
#    Merck was founded in 1668 and is the world's oldest operating chemical and pharmaceutical company, as well as one of the largest pharmaceutical companies in the world, {})],
#   'pos': [Annotation(pos, 0, 2, DT, {'word': 'The'}),
#    Annotation(pos, 4, 8, NNP, {'word': 'Merck'}),
#    Annotation(pos, 10, 14, NNP, {'word': 'Group'}),
#    Annotation(pos, 15, 15, ,, {'word': ','}),
#    Annotation(pos, 17, 23, VBD, {'word': 'branded'}),
#    Annotation(pos, 25, 27, CC, {'word': 'and'}),
#    Annotation(pos, 29, 36, RB, {'word': 'commonly'}),
#    Annotation(pos, 38, 42, VBN, {'word': 'known'}),
#    Annotation(pos, 44, 45, IN, {'word': 'as'}),
#    Annotation(pos, 47, 51, NNP, {'word': 'Merck'}),
#    Annotation(pos, 52, 52, ,, {'word': ','}),
#    Annotation(pos, 54, 55, VBZ, {'word': 'is'}),
#    Annotation(pos, 57, 57, DT, {'word': 'a'}),
#    Annotation(pos, 59, 64, JJ, {'word': 'German'}),
#    Annotation(pos, 66, 78, JJ, {'word': 'multinational'}),
#    Annotation(pos, 80, 93, JJ, {'word': 'pharmaceutical'}),
#    Annotation(pos, 94, 94, ,, {'word': ','}),
#    Annotation(pos, 96, 103, NN, {'word': 'chemical'}),
#    Annotation(pos, 105, 107, CC, {'word': 'and'}),
#    Annotation(pos, 109, 112, NN, {'word': 'life'}),
#    Annotation(pos, 114, 121, NNS, {'word': 'sciences'}),
#    Annotation(pos, 123, 129, NN, {'word': 'company'}),
#    Annotation(pos, 131, 143, VBD, {'word': 'headquartered'}),
#    Annotation(pos, 145, 146, IN, {'word': 'in'}),
#    Annotation(pos, 148, 156, NNP, {'word': 'Darmstadt'}),
#    Annotation(pos, 157, 157, ,, {'word': ','}),
#    Annotation(pos, 159, 162, IN, {'word': 'with'}),
#    Annotation(pos, 164, 168, IN, {'word': 'about'}),
#    Annotation(pos, 170, 175, CD, {'word': '56,000'}),
#    Annotation(pos, 177, 185, NNS, {'word': 'employees'}),
#    Annotation(pos, 187, 189, CC, {'word': 'and'}),
#    Annotation(pos, 191, 197, JJ, {'word': 'present'}),
#    Annotation(pos, 199, 200, IN, {'word': 'in'}),
#    Annotation(pos, 202, 203, CD, {'word': '66'}),
#    Annotation(pos, 205, 213, NNS, {'word': 'countries'}),
#    Annotation(pos, 214, 214, ., {'word': '.'}),
#    Annotation(pos, 217, 219, DT, {'word': 'The'}),
#    Annotation(pos, 221, 225, NN, {'word': 'group'}),
#    Annotation(pos, 227, 234, VBZ, {'word': 'includes'}),
#    Annotation(pos, 236, 241, IN, {'word': 'around'}),
#    Annotation(pos, 243, 245, CD, {'word': '250'}),
#    Annotation(pos, 247, 255, NNS, {'word': 'companies'}),
#    Annotation(pos, 256, 256, :, {'word': ';'}),
#    Annotation(pos, 258, 260, DT, {'word': 'the'}),
#    Annotation(pos, 262, 265, JJ, {'word': 'main'}),
#    Annotation(pos, 267, 273, NN, {'word': 'company'}),
#    Annotation(pos, 275, 276, VBZ, {'word': 'is'}),
#    Annotation(pos, 278, 282, NNP, {'word': 'Merck'}),
#    Annotation(pos, 284, 287, NNP, {'word': 'KGaA'}),
#    Annotation(pos, 289, 290, IN, {'word': 'in'}),
#    Annotation(pos, 292, 298, NNP, {'word': 'Germany'}),
#    Annotation(pos, 299, 299, ., {'word': '.'}),
#    Annotation(pos, 302, 306, NNP, {'word': 'Merck'}),
#    Annotation(pos, 308, 310, VBD, {'word': 'was'}),
#    Annotation(pos, 312, 318, VBN, {'word': 'founded'}),
#    Annotation(pos, 320, 321, IN, {'word': 'in'}),
#    Annotation(pos, 323, 326, CD, {'word': '1668'}),
#    Annotation(pos, 328, 330, CC, {'word': 'and'}),
#    Annotation(pos, 332, 333, VBZ, {'word': 'is'}),
#    Annotation(pos, 335, 337, DT, {'word': 'the'}),
#    Annotation(pos, 339, 345, NN, {'word': "world's"}),
#    Annotation(pos, 347, 352, JJS, {'word': 'oldest'}),
#    Annotation(pos, 354, 362, VBG, {'word': 'operating'}),
#    Annotation(pos, 364, 371, NN, {'word': 'chemical'}),
#    Annotation(pos, 373, 375, CC, {'word': 'and'}),
#    Annotation(pos, 377, 390, JJ, {'word': 'pharmaceutical'}),
#    Annotation(pos, 392, 398, NN, {'word': 'company'}),
#    Annotation(pos, 399, 399, ,, {'word': ','}),
#    Annotation(pos, 401, 402, RB, {'word': 'as'}),
#    Annotation(pos, 404, 407, RB, {'word': 'well'}),
#    Annotation(pos, 409, 410, IN, {'word': 'as'}),
#    Annotation(pos, 412, 414, CD, {'word': 'one'}),
#    Annotation(pos, 416, 417, IN, {'word': 'of'}),
#    Annotation(pos, 419, 421, DT, {'word': 'the'}),
#    Annotation(pos, 423, 429, JJS, {'word': 'largest'}),
#    Annotation(pos, 431, 444, JJ, {'word': 'pharmaceutical'}),
#    Annotation(pos, 446, 454, NNS, {'word': 'companies'}),
#    Annotation(pos, 456, 457, IN, {'word': 'in'}),
#    Annotation(pos, 459, 461, DT, {'word': 'the'}),
#    Annotation(pos, 463, 467, NN, {'word': 'world'})],
#   'token': [Annotation(token, 0, 2, The, {'sentence': '0'}),
#    Annotation(token, 4, 8, Merck, {'sentence': '0'}),
#    Annotation(token, 10, 14, Group, {'sentence': '0'}),
#    Annotation(token, 15, 15, ,, {'sentence': '0'}),
#    Annotation(token, 17, 23, branded, {'sentence': '0'}),
#    Annotation(token, 25, 27, and, {'sentence': '0'}),
#    Annotation(token, 29, 36, commonly, {'sentence': '0'}),
#    Annotation(token, 38, 42, known, {'sentence': '0'}),
#    Annotation(token, 44, 45, as, {'sentence': '0'}),
#    Annotation(token, 47, 51, Merck, {'sentence': '0'}),
#    Annotation(token, 52, 52, ,, {'sentence': '0'}),
#    Annotation(token, 54, 55, is, {'sentence': '0'}),
#    Annotation(token, 57, 57, a, {'sentence': '0'}),
#    Annotation(token, 59, 64, German, {'sentence': '0'}),
#    Annotation(token, 66, 78, multinational, {'sentence': '0'}),
#    Annotation(token, 80, 93, pharmaceutical, {'sentence': '0'}),
#    Annotation(token, 94, 94, ,, {'sentence': '0'}),
#    Annotation(token, 96, 103, chemical, {'sentence': '0'}),
#    Annotation(token, 105, 107, and, {'sentence': '0'}),
#    Annotation(token, 109, 112, life, {'sentence': '0'}),
#    Annotation(token, 114, 121, sciences, {'sentence': '0'}),
#    Annotation(token, 123, 129, company, {'sentence': '0'}),
#    Annotation(token, 131, 143, headquartered, {'sentence': '0'}),
#    Annotation(token, 145, 146, in, {'sentence': '0'}),
#    Annotation(token, 148, 156, Darmstadt, {'sentence': '0'}),
#    Annotation(token, 157, 157, ,, {'sentence': '0'}),
#    Annotation(token, 159, 162, with, {'sentence': '0'}),
#    Annotation(token, 164, 168, about, {'sentence': '0'}),
#    Annotation(token, 170, 175, 56,000, {'sentence': '0'}),
#    Annotation(token, 177, 185, employees, {'sentence': '0'}),
#    Annotation(token, 187, 189, and, {'sentence': '0'}),
#    Annotation(token, 191, 197, present, {'sentence': '0'}),
#    Annotation(token, 199, 200, in, {'sentence': '0'}),
#    Annotation(token, 202, 203, 66, {'sentence': '0'}),
#    Annotation(token, 205, 213, countries, {'sentence': '0'}),
#    Annotation(token, 214, 214, ., {'sentence': '0'}),
#    Annotation(token, 217, 219, The, {'sentence': '1'}),
#    Annotation(token, 221, 225, group, {'sentence': '1'}),
#    Annotation(token, 227, 234, includes, {'sentence': '1'}),
#    Annotation(token, 236, 241, around, {'sentence': '1'}),
#    Annotation(token, 243, 245, 250, {'sentence': '1'}),
#    Annotation(token, 247, 255, companies, {'sentence': '1'}),
#    Annotation(token, 256, 256, ;, {'sentence': '1'}),
#    Annotation(token, 258, 260, the, {'sentence': '2'}),
#    Annotation(token, 262, 265, main, {'sentence': '2'}),
#    Annotation(token, 267, 273, company, {'sentence': '2'}),
#    Annotation(token, 275, 276, is, {'sentence': '2'}),
#    Annotation(token, 278, 282, Merck, {'sentence': '2'}),
#    Annotation(token, 284, 287, KGaA, {'sentence': '2'}),
#    Annotation(token, 289, 290, in, {'sentence': '2'}),
#    Annotation(token, 292, 298, Germany, {'sentence': '2'}),
#    Annotation(token, 299, 299, ., {'sentence': '2'}),
#    Annotation(token, 302, 306, Merck, {'sentence': '3'}),
#    Annotation(token, 308, 310, was, {'sentence': '3'}),
#    Annotation(token, 312, 318, founded, {'sentence': '3'}),
#    Annotation(token, 320, 321, in, {'sentence': '3'}),
#    Annotation(token, 323, 326, 1668, {'sentence': '3'}),
#    Annotation(token, 328, 330, and, {'sentence': '3'}),
#    Annotation(token, 332, 333, is, {'sentence': '3'}),
#    Annotation(token, 335, 337, the, {'sentence': '3'}),
#    Annotation(token, 339, 345, world's, {'sentence': '3'}),
#    Annotation(token, 347, 352, oldest, {'sentence': '3'}),
#    Annotation(token, 354, 362, operating, {'sentence': '3'}),
#    Annotation(token, 364, 371, chemical, {'sentence': '3'}),
#    Annotation(token, 373, 375, and, {'sentence': '3'}),
#    Annotation(token, 377, 390, pharmaceutical, {'sentence': '3'}),
#    Annotation(token, 392, 398, company, {'sentence': '3'}),
#    Annotation(token, 399, 399, ,, {'sentence': '3'}),
#    Annotation(token, 401, 402, as, {'sentence': '3'}),
#    Annotation(token, 404, 407, well, {'sentence': '3'}),
#    Annotation(token, 409, 410, as, {'sentence': '3'}),
#    Annotation(token, 412, 414, one, {'sentence': '3'}),
#    Annotation(token, 416, 417, of, {'sentence': '3'}),
#    Annotation(token, 419, 421, the, {'sentence': '3'}),
#    Annotation(token, 423, 429, largest, {'sentence': '3'}),
#    Annotation(token, 431, 444, pharmaceutical, {'sentence': '3'}),
#    Annotation(token, 446, 454, companies, {'sentence': '3'}),
#    Annotation(token, 456, 457, in, {'sentence': '3'}),
#    Annotation(token, 459, 461, the, {'sentence': '3'}),
#    Annotation(token, 463, 467, world, {'sentence': '3'})],
#   'ner': [Annotation(named_entity, 0, 2, O, {'word': 'The'}),
#    Annotation(named_entity, 4, 8, B-ORG, {'word': 'Merck'}),
#    Annotation(named_entity, 10, 14, I-ORG, {'word': 'Group'}),
#    Annotation(named_entity, 15, 15, O, {'word': ','}),
#    Annotation(named_entity, 17, 23, O, {'word': 'branded'}),
#    Annotation(named_entity, 25, 27, O, {'word': 'and'}),
#    Annotation(named_entity, 29, 36, O, {'word': 'commonly'}),
#    Annotation(named_entity, 38, 42, O, {'word': 'known'}),
#    Annotation(named_entity, 44, 45, O, {'word': 'as'}),
#    Annotation(named_entity, 47, 51, B-ORG, {'word': 'Merck'}),
#    Annotation(named_entity, 52, 52, O, {'word': ','}),
#    Annotation(named_entity, 54, 55, O, {'word': 'is'}),
#    Annotation(named_entity, 57, 57, O, {'word': 'a'}),
#    Annotation(named_entity, 59, 64, B-MISC, {'word': 'German'}),
#    Annotation(named_entity, 66, 78, O, {'word': 'multinational'}),
#    Annotation(named_entity, 80, 93, O, {'word': 'pharmaceutical'}),
#    Annotation(named_entity, 94, 94, O, {'word': ','}),
#    Annotation(named_entity, 96, 103, O, {'word': 'chemical'}),
#    Annotation(named_entity, 105, 107, O, {'word': 'and'}),
#    Annotation(named_entity, 109, 112, O, {'word': 'life'}),
#    Annotation(named_entity, 114, 121, O, {'word': 'sciences'}),
#    Annotation(named_entity, 123, 129, O, {'word': 'company'}),
#    Annotation(named_entity, 131, 143, O, {'word': 'headquartered'}),
#    Annotation(named_entity, 145, 146, O, {'word': 'in'}),
#    Annotation(named_entity, 148, 156, B-LOC, {'word': 'Darmstadt'}),
#    Annotation(named_entity, 157, 157, O, {'word': ','}),
#    Annotation(named_entity, 159, 162, O, {'word': 'with'}),
#    Annotation(named_entity, 164, 168, O, {'word': 'about'}),
#    Annotation(named_entity, 170, 175, O, {'word': '56,000'}),
#    Annotation(named_entity, 177, 185, O, {'word': 'employees'}),
#    Annotation(named_entity, 187, 189, O, {'word': 'and'}),
#    Annotation(named_entity, 191, 197, O, {'word': 'present'}),
#    Annotation(named_entity, 199, 200, O, {'word': 'in'}),
#    Annotation(named_entity, 202, 203, O, {'word': '66'}),
#    Annotation(named_entity, 205, 213, O, {'word': 'countries'}),
#    Annotation(named_entity, 214, 214, O, {'word': '.'}),
#    Annotation(named_entity, 217, 219, O, {'word': 'The'}),
#    Annotation(named_entity, 221, 225, O, {'word': 'group'}),
#    Annotation(named_entity, 227, 234, O, {'word': 'includes'}),
#    Annotation(named_entity, 236, 241, O, {'word': 'around'}),
#    Annotation(named_entity, 243, 245, O, {'word': '250'}),
#    Annotation(named_entity, 247, 255, O, {'word': 'companies'}),
#    Annotation(named_entity, 256, 256, O, {'word': ';'}),
#    Annotation(named_entity, 258, 260, O, {'word': 'the'}),
#    Annotation(named_entity, 262, 265, O, {'word': 'main'}),
#    Annotation(named_entity, 267, 273, O, {'word': 'company'}),
#    Annotation(named_entity, 275, 276, O, {'word': 'is'}),
#    Annotation(named_entity, 278, 282, B-ORG, {'word': 'Merck'}),
#    Annotation(named_entity, 284, 287, I-ORG, {'word': 'KGaA'}),
#    Annotation(named_entity, 289, 290, O, {'word': 'in'}),
#    Annotation(named_entity, 292, 298, B-LOC, {'word': 'Germany'}),
#    Annotation(named_entity, 299, 299, O, {'word': '.'}),
#    Annotation(named_entity, 302, 306, B-ORG, {'word': 'Merck'}),
#    Annotation(named_entity, 308, 310, O, {'word': 'was'}),
#    Annotation(named_entity, 312, 318, O, {'word': 'founded'}),
#    Annotation(named_entity, 320, 321, O, {'word': 'in'}),
#    Annotation(named_entity, 323, 326, O, {'word': '1668'}),
#    Annotation(named_entity, 328, 330, O, {'word': 'and'}),
#    Annotation(named_entity, 332, 333, O, {'word': 'is'}),
#    Annotation(named_entity, 335, 337, O, {'word': 'the'}),
#    Annotation(named_entity, 339, 345, O, {'word': "world's"}),
#    Annotation(named_entity, 347, 352, O, {'word': 'oldest'}),
#    Annotation(named_entity, 354, 362, O, {'word': 'operating'}),
#    Annotation(named_entity, 364, 371, O, {'word': 'chemical'}),
#    Annotation(named_entity, 373, 375, O, {'word': 'and'}),
#    Annotation(named_entity, 377, 390, O, {'word': 'pharmaceutical'}),
#    Annotation(named_entity, 392, 398, O, {'word': 'company'}),
#    Annotation(named_entity, 399, 399, O, {'word': ','}),
#    Annotation(named_entity, 401, 402, O, {'word': 'as'}),
#    Annotation(named_entity, 404, 407, O, {'word': 'well'}),
#    Annotation(named_entity, 409, 410, O, {'word': 'as'}),
#    Annotation(named_entity, 412, 414, O, {'word': 'one'}),
#    Annotation(named_entity, 416, 417, O, {'word': 'of'}),
#    Annotation(named_entity, 419, 421, O, {'word': 'the'}),
#    Annotation(named_entity, 423, 429, O, {'word': 'largest'}),
#    Annotation(named_entity, 431, 444, O, {'word': 'pharmaceutical'}),
#    Annotation(named_entity, 446, 454, O, {'word': 'companies'}),
#    Annotation(named_entity, 456, 457, O, {'word': 'in'}),
#    Annotation(named_entity, 459, 461, O, {'word': 'the'}),
#    Annotation(named_entity, 463, 467, O, {'word': 'world'})],
#   'embeddings': [Annotation(word_embeddings, 0, 2, The, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'The', 'sentence': '0'}),
#    Annotation(word_embeddings, 4, 8, Merck, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'Merck', 'sentence': '0'}),
#    Annotation(word_embeddings, 10, 14, Group, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'Group', 'sentence': '0'}),
#    Annotation(word_embeddings, 15, 15, ,, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': ',', 'sentence': '0'}),
#    Annotation(word_embeddings, 17, 23, branded, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'branded', 'sentence': '0'}),
#    Annotation(word_embeddings, 25, 27, and, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'and', 'sentence': '0'}),
#    Annotation(word_embeddings, 29, 36, commonly, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'commonly', 'sentence': '0'}),
#    Annotation(word_embeddings, 38, 42, known, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'known', 'sentence': '0'}),
#    Annotation(word_embeddings, 44, 45, as, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'as', 'sentence': '0'}),
#    Annotation(word_embeddings, 47, 51, Merck, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'Merck', 'sentence': '0'}),
#    Annotation(word_embeddings, 52, 52, ,, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': ',', 'sentence': '0'}),
#    Annotation(word_embeddings, 54, 55, is, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'is', 'sentence': '0'}),
#    Annotation(word_embeddings, 57, 57, a, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'a', 'sentence': '0'}),
#    Annotation(word_embeddings, 59, 64, German, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'German', 'sentence': '0'}),
#    Annotation(word_embeddings, 66, 78, multinational, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'multinational', 'sentence': '0'}),
#    Annotation(word_embeddings, 80, 93, pharmaceutical, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'pharmaceutical', 'sentence': '0'}),
#    Annotation(word_embeddings, 94, 94, ,, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': ',', 'sentence': '0'}),
#    Annotation(word_embeddings, 96, 103, chemical, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'chemical', 'sentence': '0'}),
#    Annotation(word_embeddings, 105, 107, and, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'and', 'sentence': '0'}),
#    Annotation(word_embeddings, 109, 112, life, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'life', 'sentence': '0'}),
#    Annotation(word_embeddings, 114, 121, sciences, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'sciences', 'sentence': '0'}),
#    Annotation(word_embeddings, 123, 129, company, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'company', 'sentence': '0'}),
#    Annotation(word_embeddings, 131, 143, headquartered, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'headquartered', 'sentence': '0'}),
#    Annotation(word_embeddings, 145, 146, in, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'in', 'sentence': '0'}),
#    Annotation(word_embeddings, 148, 156, Darmstadt, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'Darmstadt', 'sentence': '0'}),
#    Annotation(word_embeddings, 157, 157, ,, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': ',', 'sentence': '0'}),
#    Annotation(word_embeddings, 159, 162, with, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'with', 'sentence': '0'}),
#    Annotation(word_embeddings, 164, 168, about, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'about', 'sentence': '0'}),
#    Annotation(word_embeddings, 170, 175, 56,000, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': '56,000', 'sentence': '0'}),
#    Annotation(word_embeddings, 177, 185, employees, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'employees', 'sentence': '0'}),
#    Annotation(word_embeddings, 187, 189, and, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'and', 'sentence': '0'}),
#    Annotation(word_embeddings, 191, 197, present, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'present', 'sentence': '0'}),
#    Annotation(word_embeddings, 199, 200, in, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'in', 'sentence': '0'}),
#    Annotation(word_embeddings, 202, 203, 66, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': '66', 'sentence': '0'}),
#    Annotation(word_embeddings, 205, 213, countries, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'countries', 'sentence': '0'}),
#    Annotation(word_embeddings, 214, 214, ., {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': '.', 'sentence': '0'}),
#    Annotation(word_embeddings, 217, 219, The, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'The', 'sentence': '1'}),
#    Annotation(word_embeddings, 221, 225, group, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'group', 'sentence': '1'}),
#    Annotation(word_embeddings, 227, 234, includes, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'includes', 'sentence': '1'}),
#    Annotation(word_embeddings, 236, 241, around, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'around', 'sentence': '1'}),
#    Annotation(word_embeddings, 243, 245, 250, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': '250', 'sentence': '1'}),
#    Annotation(word_embeddings, 247, 255, companies, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'companies', 'sentence': '1'}),
#    Annotation(word_embeddings, 256, 256, ;, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': ';', 'sentence': '1'}),
#    Annotation(word_embeddings, 258, 260, the, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'the', 'sentence': '2'}),
#    Annotation(word_embeddings, 262, 265, main, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'main', 'sentence': '2'}),
#    Annotation(word_embeddings, 267, 273, company, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'company', 'sentence': '2'}),
#    Annotation(word_embeddings, 275, 276, is, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'is', 'sentence': '2'}),
#    Annotation(word_embeddings, 278, 282, Merck, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'Merck', 'sentence': '2'}),
#    Annotation(word_embeddings, 284, 287, KGaA, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'KGaA', 'sentence': '2'}),
#    Annotation(word_embeddings, 289, 290, in, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'in', 'sentence': '2'}),
#    Annotation(word_embeddings, 292, 298, Germany, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'Germany', 'sentence': '2'}),
#    Annotation(word_embeddings, 299, 299, ., {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': '.', 'sentence': '2'}),
#    Annotation(word_embeddings, 302, 306, Merck, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'Merck', 'sentence': '3'}),
#    Annotation(word_embeddings, 308, 310, was, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'was', 'sentence': '3'}),
#    Annotation(word_embeddings, 312, 318, founded, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'founded', 'sentence': '3'}),
#    Annotation(word_embeddings, 320, 321, in, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'in', 'sentence': '3'}),
#    Annotation(word_embeddings, 323, 326, 1668, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': '1668', 'sentence': '3'}),
#    Annotation(word_embeddings, 328, 330, and, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'and', 'sentence': '3'}),
#    Annotation(word_embeddings, 332, 333, is, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'is', 'sentence': '3'}),
#    Annotation(word_embeddings, 335, 337, the, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'the', 'sentence': '3'}),
#    Annotation(word_embeddings, 339, 345, world's, {'isOOV': 'true', 'pieceId': '-1', 'isWordStart': 'true', 'token': "world's", 'sentence': '3'}),
#    Annotation(word_embeddings, 347, 352, oldest, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'oldest', 'sentence': '3'}),
#    Annotation(word_embeddings, 354, 362, operating, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'operating', 'sentence': '3'}),
#    Annotation(word_embeddings, 364, 371, chemical, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'chemical', 'sentence': '3'}),
#    Annotation(word_embeddings, 373, 375, and, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'and', 'sentence': '3'}),
#    Annotation(word_embeddings, 377, 390, pharmaceutical, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'pharmaceutical', 'sentence': '3'}),
#    Annotation(word_embeddings, 392, 398, company, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'company', 'sentence': '3'}),
#    Annotation(word_embeddings, 399, 399, ,, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': ',', 'sentence': '3'}),
#    Annotation(word_embeddings, 401, 402, as, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'as', 'sentence': '3'}),
#    Annotation(word_embeddings, 404, 407, well, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'well', 'sentence': '3'}),
#    Annotation(word_embeddings, 409, 410, as, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'as', 'sentence': '3'}),
#    Annotation(word_embeddings, 412, 414, one, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'one', 'sentence': '3'}),
#    Annotation(word_embeddings, 416, 417, of, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'of', 'sentence': '3'}),
#    Annotation(word_embeddings, 419, 421, the, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'the', 'sentence': '3'}),
#    Annotation(word_embeddings, 423, 429, largest, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'largest', 'sentence': '3'}),
#    Annotation(word_embeddings, 431, 444, pharmaceutical, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'pharmaceutical', 'sentence': '3'}),
#    Annotation(word_embeddings, 446, 454, companies, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'companies', 'sentence': '3'}),
#    Annotation(word_embeddings, 456, 457, in, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'in', 'sentence': '3'}),
#    Annotation(word_embeddings, 459, 461, the, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'the', 'sentence': '3'}),
#    Annotation(word_embeddings, 463, 467, world, {'isOOV': 'false', 'pieceId': '-1', 'isWordStart': 'true', 'token': 'world', 'sentence': '3'})],
#   'sentence': [Annotation(document, 0, 214, The Merck Group, branded and commonly known as Merck, is a German multinational pharmaceutical, chemical and life sciences company headquartered in Darmstadt, with about 56,000 employees and present in 66 countries., {'sentence': '0'}),
#    Annotation(document, 217, 256, The group includes around 250 companies;, {'sentence': '1'}),
#    Annotation(document, 258, 299, the main company is Merck KGaA in Germany., {'sentence': '2'}),
#    Annotation(document, 302, 467, Merck was founded in 1668 and is the world's oldest operating chemical and pharmaceutical company, as well as one of the largest pharmaceutical companies in the world, {'sentence': '3'})]}]

# %%
detailed_result_explain_dl[0]['entities']
# Out:
# [Annotation(chunk, 4, 14, Merck Group, {'entity': 'ORG', 'sentence': '0', 'chunk': '0'}),
#  Annotation(chunk, 47, 51, Merck, {'entity': 'ORG', 'sentence': '0', 'chunk': '1'}),
#  Annotation(chunk, 59, 64, German, {'entity': 'MISC', 'sentence': '0', 'chunk': '2'}),
#  Annotation(chunk, 148, 156, Darmstadt, {'entity': 'LOC', 'sentence': '0', 'chunk': '3'}),
#  Annotation(chunk, 278, 287, Merck KGaA, {'entity': 'ORG', 'sentence': '2', 'chunk': '4'}),
#  Annotation(chunk, 292, 298, Germany, {'entity': 'LOC', 'sentence': '2', 'chunk': '5'}),
#  Annotation(chunk, 302, 306, Merck, {'entity': 'ORG', 'sentence': '3', 'chunk': '6'})]

# %%
chunks=[]
entities=[]
for n in detailed_result_explain_dl[0]['entities']:
        
  chunks.append(n.result)
  entities.append(n.metadata['entity']) 
    
df = pd.DataFrame({'chunks':chunks, 'entities':entities})
df
# Out:
#         chunks entities
# 0  Merck Group      ORG
# 1        Merck      ORG
# 2       German     MISC
# 3    Darmstadt      LOC
# 4   Merck KGaA      ORG
# 5      Germany      LOC
# 6        Merck      ORG

# %%
tuples = []

for x,y,z in zip(detailed_result_explain_dl[0]["token"], detailed_result_explain_dl[0]["pos"], detailed_result_explain_dl[0]["ner"]):

  tuples.append((int(x.metadata['sentence']), x.result, x.begin, x.end, y.result, z.result))

df = pd.DataFrame(tuples, columns=['sent_id','token','start','end','pos', 'ner'])

df.head(10)
# Out:
#    sent_id     token  start  end  pos    ner
# 0        0       The      0    2   DT      O
# 1        0     Merck      4    8  NNP  B-ORG
# 2        0     Group     10   14  NNP  I-ORG
# 3        0         ,     15   15    ,      O
# 4        0   branded     17   23  VBD      O
# 5        0       and     25   27   CC      O
# 6        0  commonly     29   36   RB      O
# 7        0     known     38   42  VBN      O
# 8        0        as     44   45   IN      O
# 9        0     Merck     47   51  NNP  B-ORG

# %% [markdown]
# ### Clean Stop words
# <a id='section3'></a>

# %%
clean_stop=PretrainedPipeline.from_disk("/dfs/is/home/m292915/spark_nlp/sparknlp_pipelines/clean_stop_en")
result_clean_stop = clean_stop.annotate(text)
print(' '.join(result_clean_stop['token']))
# Out:
# The Merck Group , branded and commonly known as Merck , is a German multinational pharmaceutical , chemical and life sciences company headquartered in Darmstadt , with about 56,000 employees and present in 66 countries . The group includes around 250 companies ; the main company is Merck KGaA in Germany . Merck was founded in 1668 and is the world's oldest operating chemical and pharmaceutical company , as well as one of the largest pharmaceutical companies in the world

# %% [markdown]
# <a id='section4'></a>
# ### Entity Recognization

# %%
recognize_entities = PretrainedPipeline.from_disk('/dfs/is/home/m292915/spark_nlp/sparknlp_pipelines/recognize_entities_dl_en')

# %%
doc_entity_rec = '''
Peter is a very good persn.
He has a good car though.
Europe is very culture rich.
'''

# %%
result_recognize_entities = recognize_entities.annotate(doc_entity_rec)
pd.DataFrame({'word':result_recognize_entities['token'],"corrected_word":result_recognize_entities['ner']})
# Out:
#        word corrected_word
# 0     Peter          B-PER
# 1        is              O
# 2         a              O
# 3      very              O
# 4      good              O
# 5     persn              O
# 6         .              O
# 7        He              O
# 8       has              O
# 9         a              O
# 10     good              O
# 11      car              O
# 12   though              O
# 13        .              O
# 14   Europe          B-LOC
# 15       is              O
# 16     very              O
# 17  culture              O
# 18     rich              O
# 19        .              O

# %% [markdown]
# ### V. Clean slang
# <a id='section5'></a>

# %%
clean_slang = PretrainedPipeline.from_disk('/dfs/is/home/m292915/spark_nlp/sparknlp_pipelines/clean_slang_en')
result_clean_slang = clean_slang.annotate(' Whatsup bro, call me ASAP')
print(' '.join(result_clean_slang['normal']))
# Out:
# how are you friend call me as soon as possible

# %% [markdown]
# ### Spell Checker
# <a id='section6'></a>

# %%
spell_checker_ml = PretrainedPipeline.from_disk('/dfs/is/home/m292915/spark_nlp/sparknlp_pipelines/check_spelling_en')

# %%
#spell_checker_dl = PretrainedPipeline.from_disk('/dfs/is/home/m292915/spark_nlp/sparknlp_pipelines/check_spelling_dl')

# %%
text_spell_check = '''
He is a  good persn.
My life  is very intersting.
We are brothrs.
'''

# %%
result_spell_checker_ml = spell_checker_ml.annotate(text_spell_check)
#result_spell_checker_dl = spell_checker_dl.annotate(text_spell_check)
pd.DataFrame({'word':result_spell_checker_ml['token'],"corrected_word":result_spell_checker_ml['checked']})
# Out:
#           word corrected_word
# 0           He             He
# 1           is             is
# 2            a              a
# 3         good           good
# 4        persn         person
# 5            .              .
# 6           My             My
# 7         life           life
# 8           is             is
# 9         very           very
# 10  intersting    interesting
# 11           .              .
# 12          We             We
# 13         are            are
# 14     brothrs       brothers
# 15           .              .

# %% [markdown]
# <a id='section7'></a>
# ### Sentiment Analysis

# %%
sentiment = PretrainedPipeline.from_disk('/dfs/is/home/m292915/spark_nlp/sparknlp_pipelines/analyze_sentiment_en')
result_sentiment = sentiment.annotate("The movie I watched today was not a good one")
result_sentiment['sentiment']
# Out:
# ['negative']

# %% [markdown]
# <a id='section8'></a>
# ### Matching chunks

# %%
matching_chunks = PretrainedPipeline.from_disk('/dfs/is/home/m292915/spark_nlp/sparknlp_pipelines/match_chunks_en')
result_matching_chunks = matching_chunks.annotate("The book has many chapters") # single noun phrase
result_matching_chunks
# Out:
# {'chunk': ['The book'],
#  'document': ['The book has many chapters'],
#  'pos': ['DT', 'NN', 'VBZ', 'JJ', 'NNS'],
#  'token': ['The', 'book', 'has', 'many', 'chapters'],
#  'sentence': ['The book has many chapters']}

# %%
result_matching_chunks = matching_chunks.annotate("the little yellow dog barked at the cat") #multiple noune phrases
result_matching_chunks
# Out:
# {'chunk': ['the little yellow dog', 'the cat'],
#  'document': ['the little yellow dog barked at the cat'],
#  'pos': ['DT', 'JJ', 'JJ', 'NN', 'JJ', 'IN', 'DT', 'NN'],
#  'token': ['the', 'little', 'yellow', 'dog', 'barked', 'at', 'the', 'cat'],
#  'sentence': ['the little yellow dog barked at the cat']}

# %% [markdown]
# <a id='section9'></a>
# ### Extract Exact Dates from Referential Date Phrases

# %%
match_datetime_en= PretrainedPipeline.from_disk('/dfs/is/home/m292915/spark_nlp/sparknlp_pipelines/match_datetime_en')

# %%
result_match_datetime_en = match_datetime_en.annotate("I saw him yesterday and he told me that he will visit us next week")

# %%
detailed_result_match_datetime_en = match_datetime_en.fullAnnotate("I saw him yesterday and he told me that he will visit us next week")
detailed_result_match_datetime_en
